# %% [markdown]
# <a href="https://colab.research.google.com/github/SwekeR-463/NLP-Basics/blob/main/StopWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stop words are words that are removed from natural language data before or after processing because they are considered insignificant.

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# All the stop words in spacy.

# %%
spacy.lang.en.stop_words.STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
text = "Natural language processing (NLP) is a subfield of artificial intelligence (AI) that allows computers to understand human language, both spoken and written."

# %%
doc = nlp(text)

# %%
for t in doc:
  if not t.is_stop:
    print(t.text)
# Out:
# Natural
# language
# processing
# (
# NLP
# )
# subfield
# artificial
# intelligence
# (
# AI
# )
# allows
# computers
# understand
# human
# language
# ,
# spoken
# written
# .
